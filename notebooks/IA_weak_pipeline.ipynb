# %% [markdown]
# # Weak supervision pipeline
#
# ## What does this notebook do?
#
# This notebook is an initial rough pipeline for developing and applying weak labels to images of book pages from the internet archive. The goal is to use weak supervision to apply labels to these images indicating if the page is illustrated or not.
#
# ## Data used
# This notebook uses the following two datasets:
#
# ### [ImageIN/ImageIn_annotations](https://huggingface.co/datasets/ImageIN/ImageIn_annotations)
#
# This is a subset of images of book pages sampled from the internet archive with annotations for whether the page contains an illustration or not. This dataset serves as the ground truth to support the development and evaluation of weak labelling functions.
#
# ### [ImageIN/IA_loaded](https://huggingface.co/datasets/ImageIN/IA_loaded)
#
# This is a subset of images of book pages sampled from the internet archive with no labels.

# %%
# %pip install datasets wandb transformers timm sklearn snorkel piffle requests-cache httpx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.5.1-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 7.6 MB/s
# Collecting wandb
#   Downloading wandb-0.13.3-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 81.0 MB/s
# Collecting transformers
#   Downloading transformers-4.22.2-py3-none-any.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 57.1 MB/s
# Collecting timm
#   Downloading timm-0.6.11-py3-none-any.whl (548 kB)
#      |████████████████████████████████| 548 kB 72.2 MB/s
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting snorkel
#   Downloading snorkel-0.9.9-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 86.5 MB/s
# Collecting piffle
#   Downloading piffle-0.4.0-py2.py3-none-any.whl (15 kB)
# Collecting requests-cache
#   Downloading requests_cache-0.9.6-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 5.1 MB/s
# Collecting httpx
#   Downloading httpx-0.23.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 4.4 MB/s
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 103.9 MB/s
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Downloading huggingface_hub-0.10.0-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 91.7 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 89.7 MB/s
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.8.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.12.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 70.7 MB/s
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: protobuf<4.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 93.4 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.10-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 94.3 MB/s
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.8 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.9-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 75.6 MB/s
#   Downloading sentry_sdk-1.9.8-py2.py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 60.7 MB/s
#   Downloading sentry_sdk-1.9.7-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 63.4 MB/s
#   Downloading sentry_sdk-1.9.6-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 56.0 MB/s
#   Downloading sentry_sdk-1.9.5-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 72.5 MB/s
#   Downloading sentry_sdk-1.9.4-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 58.7 MB/s
#   Downloading sentry_sdk-1.9.3-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 62.5 MB/s
#   Downloading sentry_sdk-1.9.2-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 87.6 MB/s
#   Downloading sentry_sdk-1.9.1-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 63.2 MB/s
#   Downloading sentry_sdk-1.9.0-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 77.5 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 53.6 MB/s
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.7/dist-packages (from timm) (1.12.1+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.13.1+cu113)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn) (1.0.2)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from snorkel) (1.7.3)
# Collecting tensorboard>=2.9.1
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 51.9 MB/s
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.7/dist-packages (from snorkel) (2.6.3)
# Collecting munkres>=1.0.6
#   Downloading munkres-1.1.4-py2.py3-none-any.whl (7.0 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->snorkel) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->snorkel) (1.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->snorkel) (1.35.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->snorkel) (0.37.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->snorkel) (1.48.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->snorkel) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->snorkel) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->snorkel) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->snorkel) (1.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->snorkel) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->snorkel) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->snorkel) (3.2.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from piffle) (1.5.2)
# Collecting attrdict
#   Downloading attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Collecting url-normalize>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from requests-cache) (1.4.4)
# Collecting cattrs>=1.8
#   Downloading cattrs-22.2.0-py3-none-any.whl (35 kB)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.0.0rc9-py3-none-any.whl (12 kB)
# Collecting httpcore<0.16.0,>=0.15.0
#   Downloading httpcore-0.15.0-py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 8.0 MB/s
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting anyio==3.*
#   Downloading anyio-3.6.1-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 10.8 MB/s
# Collecting h11<0.13,>=0.11
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 4.2 MB/s
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Building wheels for collected packages: sklearn, pathtools
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=91659bf0051072668a8712f19afdf9489481bfc3ccf23bfb0dbca2945a8df81c
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=6351e5d53ab17dad0cf56fa3469c76610b8effcdf90b342b863c8f0ffac68701
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built sklearn pathtools
# Installing collected packages: urllib3, sniffio, smmap, rfc3986, h11, gitdb, exceptiongroup, anyio, xxhash, url-normalize, tokenizers, tensorboard, shortuuid, setproctitle, sentry-sdk, responses, pathtools, munkres, multiprocess, huggingface-hub, httpcore, GitPython, docker-pycreds, cattrs, attrdict, wandb, transformers, timm, snorkel, sklearn, requests-cache, piffle, httpx, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.2+zzzcolab20220719082949 requires tensorboard<2.9,>=2.8, but you have tensorboard 2.10.1 which is incompatible.
# Successfully installed GitPython-3.1.27 anyio-3.6.1 attrdict-2.0.1 cattrs-22.2.0 datasets-2.5.1 docker-pycreds-0.4.0 exceptiongroup-1.0.0rc9 gitdb-4.0.9 h11-0.12.0 httpcore-0.15.0 httpx-0.23.0 huggingface-hub-0.10.0 multiprocess-0.70.13 munkres-1.1.4 pathtools-0.1.2 piffle-0.4.0 requests-cache-0.9.6 responses-0.18.0 rfc3986-1.5.0 sentry-sdk-1.9.0 setproctitle-1.3.2 shortuuid-1.0.9 sklearn-0.0 smmap-5.0.0 sniffio-1.3.0 snorkel-0.9.9 tensorboard-2.10.1 timm-0.6.11 tokenizers-0.12.1 transformers-4.22.2 url-normalize-1.4.3 urllib3-1.25.11 wandb-0.13.3 xxhash-3.0.0

# %% [markdown]
# We need to be authenticated to access some of the datasets stored on the 🤗 hub and in order to push our annotated dataset to the hub.

# %%
from huggingface_hub import notebook_login

# %%
notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token

# %%
from datasets import load_dataset

# %% [markdown]
# We load both of our datasets. One contains labels which we'll use to evaluate whether a label function is useful or not. The other is not annotated at all.

# %%
LABELLED_DATASET = "ImageIN/ImageIn_annotations"
UNLABELLED_DATASET = "davanstrien/IA_loaded"

# %%
labelled_ds = load_dataset(LABELLED_DATASET, split="train")
unlabelled_ds = load_dataset(UNLABELLED_DATASET, split="train", use_auth_token=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_deprecation.py:97: FutureWarning: Deprecated argument(s) used in 'dataset_info': token. Will not be supported from version '0.12'.
#   warnings.warn(message, FutureWarning)
# Downloading:   0%|          | 0.00/2.23k [00:00<?, ?B/s]
# WARNING:datasets.builder:Using custom data configuration ImageIN--ImageIn_annotations-3c053cc2ce1c24bf
# Downloading and preparing dataset None/None (download: 1.81 GiB, generated: 1.84 GiB, post-processed: Unknown size, total: 3.65 GiB) to /root/.cache/huggingface/datasets/ImageIN___parquet/ImageIN--ImageIn_annotations-3c053cc2ce1c24bf/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/477M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/493M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/503M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/467M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/ImageIN___parquet/ImageIN--ImageIn_annotations-3c053cc2ce1c24bf/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_deprecation.py:97: FutureWarning: Deprecated argument(s) used in 'dataset_info': token. Will not be supported from version '0.12'.
#   warnings.warn(message, FutureWarning)
# Downloading:   0%|          | 0.00/1.37k [00:00<?, ?B/s]
# WARNING:datasets.builder:Using custom data configuration davanstrien--IA_loaded-aa0d3d0c4ebca489
# Downloading and preparing dataset None/None (download: 1.02 GiB, generated: 712.20 MiB, post-processed: Unknown size, total: 1.72 GiB) to /root/.cache/huggingface/datasets/davanstrien___parquet/davanstrien--IA_loaded-aa0d3d0c4ebca489/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/550M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/davanstrien___parquet/davanstrien--IA_loaded-aa0d3d0c4ebca489/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.

# %%
unlabelled_ds
# Out:
# Dataset({
#     features: ['image', 'manifest_url', 'license', 'label', 'attribution', 'loaded_image', 'detr_preds_count', 'manuscript_count', 'mean_rgb', 'illustration_classifier'],
#     num_rows: 66836
# })

# %%
from httpx import ReadTimeout
from PIL import UnidentifiedImageError
import PIL
from httpx import HTTPError
from datasets import load_dataset_builder
from transformers import pipeline
from transformers import AutoModelForObjectDetection, AutoFeatureExtractor
import dask.dataframe as dd
from piffle.image import IIIFImageClient, ParseError
from PIL import Image
from typing import Optional
import io
from requests_cache import CachedSession
import requests
import numpy as np
from PIL import UnidentifiedImageError
from sklearn.model_selection import train_test_split

# %% [markdown]
# Quickly compare the columns to see what we have in our data.

# %%
labelled_ds[0]
# Out:
# {'image': 'https://iiif.archivelab.org/iiif/holylandbiblebok0000cunn$49/full/full/0/default.jpg',
#  'manifest_url': 'https://iiif.archivelab.org/iiif/holylandbiblebok0000cunn/manifest.json',
#  'license': '',
#  'label': '34',
#  'attribution': 'The Internet Archive',
#  'id': 11967,
#  'choice': 'not-illustrated',
#  'annotator': 1,
#  'annotation_id': 6063,
#  'created_at': Timestamp('2022-09-26 09:58:03.514234+0000', tz='UTC'),
#  'updated_at': Timestamp('2022-09-26 09:58:03.514258+0000', tz='UTC'),
#  'lead_time': 3.618,
#  'loaded_image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1757x3005 at 0x7F209D7C4690>}

# %%
unlabelled_ds[0]
# Out:
# {'image': 'https://iiif.archivelab.org/iiif/historicalcollec01howe_1$258/full/full/0/default.jpg',
#  'manifest_url': 'https://iiif.archivelab.org/iiif/historicalcollec01howe_1/manifest.json',
#  'license': None,
#  'label': '263',
#  'attribution': 'The Internet Archive',
#  'loaded_image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x7F244A69B0D0>}

# %%
def resize_url_image(url):
    try:
        iiif = IIIFImageClient.init_from_url(url)
        iiif.size = "250,250"
        return iiif.__str__()
    except ParseError:
        return None

# %% [markdown]
# ## Labelling functions
#
# Below we generate some additional columns for our data that we can use as data points for labelling functions. Normally we would do this work inside a labelling function but because some of these functions are expensive to run we do it upfront and save the results.

# %% [markdown]
# ### Heuristics
#
# One simple indicator of whether a page is illustrated is the mean RGB values of an image. Some images in our dataset are blank. We would expect these to not be illustrated and also be quite easy to detect using the mean RGB value for that image. The below function returns the mean rgb value for an image which we can then use inside a labelling function.

# %%
def calculate_mean_rgb_values(image: PIL.Image) -> Optional[float]:
    if image is None:
        return None
    image = image.convert("RGB")
    image_array = np.asarray(image)
    return np.mean(image_array)

# %% [markdown]
# ## Existing models
#
# We may be able to leverage existing computer vision models to generate some potential signal for weak labels.

# %% [markdown]
# ### Generic object detection model
#
# This function returns the predictions of an [object detection model](https://huggingface.co/facebook/detr-resnet-50) trained end-to-end on COCO 2017 object detection.

# %%
detr_pipe = pipeline("object-detection", device=0)
# Out:
# No model was supplied, defaulted to facebook/detr-resnet-50 and revision 2729413 (https://huggingface.co/facebook/detr-resnet-50).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading:   0%|          | 0.00/4.59k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/167M [00:00<?, ?B/s]
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth" to /root/.cache/torch/hub/checkpoints/resnet50_a1_0-14fe96d1.pth
# Downloading:   0%|          | 0.00/274 [00:00<?, ?B/s]

# %%
preds = detr_pipe(labelled_ds[:16]["loaded_image"])
preds
# Out:
# [[],
#  [],
#  [{'score': 0.9938995838165283,
#    'label': 'book',
#    'box': {'xmin': 0, 'ymin': 20, 'xmax': 2505, 'ymax': 3322}}],
#  [],
#  [{'score': 0.9972436428070068,
#    'label': 'book',
#    'box': {'xmin': 4, 'ymin': 14, 'xmax': 2412, 'ymax': 3442}}],
#  [{'score': 0.9922118186950684,
#    'label': 'book',
#    'box': {'xmin': 7, 'ymin': 48, 'xmax': 2488, 'ymax': 3369}}],
#  [],
#  [{'score': 0.9844426512718201,
#    'label': 'book',
#    'box': {'xmin': 0, 'ymin': 0, 'xmax': 2146, 'ymax': 3372}}],
#  [],
#  [],
#  [{'score': 0.9604831337928772,
#    'label': 'book',
#    'box': {'xmin': -5, 'ymin': 0, 'xmax': 1973, 'ymax': 3261}}],
#  [{'score': 0.9940760135650635,
#    'label': 'book',
#    'box': {'xmin': -2, 'ymin': 2, 'xmax': 2136, 'ymax': 3519}}],
#  [],
#  [],
#  [],
#  []]

# %%
def get_detr_object_count(image_batch):
    try:
        return detr_pipe(image_batch)
    except Exception:
        return [None] * len(image_batch)

# %% [markdown]
# ### Illustration bounding box detection model

# %%
model_id = "biglam/detr-resnet-50_fine_tuned_nls_chapbooks"

# %%
model = AutoModelForObjectDetection.from_pretrained(model_id)
extractor = AutoFeatureExtractor.from_pretrained(model_id)

# %%
manu_pipe = pipeline(
    "object-detection", model=model, feature_extractor=extractor, device=0
)

# %%
def get_manuscript_illustration_model_object_count(image_batch):
    try:
        return manu_pipe(image_batch)
    except Exception:
        return [None] * len(image_batch)

# %% [markdown]
# ### Baseline illustration classification model

# %%
from transformers import AutoModelForImageClassification

model_id = "ImageIN/convnext-base-224_finetuned_on_ImageIn_annotations"
model = AutoModelForImageClassification.from_pretrained(model_id)
extractor = AutoFeatureExtractor.from_pretrained(model_id)

# %%
illustration_classifier = pipeline(
    "image-classification", model=model, feature_extractor=extractor, device=0
)

# %%
illustration_classifier(labelled_ds[0]["loaded_image"])
# Out:
# [{'score': 0.9981074333190918, 'label': 'not-illustrated'},
#  {'score': 0.001892568077892065, 'label': 'illustrated'}]

# %%
def get_illustration_classifier(image_batch):
    try:
        return illustration_classifier(image_batch)
    except Exception:
        # return None
        return [None] * len(image_batch)

# %%
def pre_process(batch):
    images = batch["loaded_image"]
    return {
        "detr_preds_count": get_detr_object_count(images),
        "manuscript_count": get_manuscript_illustration_model_object_count(images),
        "mean_rgb": [calculate_mean_rgb_values(image) for image in images],
        "illustration_classifier": get_illustration_classifier(images),
    }

# %%
labelled_ds = labelled_ds.map(pre_process,
                batched=True, 
                batch_size=512,
                writer_batch_size=1024)
# Out:
#   0%|          | 0/4 [00:00<?, ?ba/s]

# %%
labelled_ds
# Out:
# Dataset({
#     features: ['image', 'manifest_url', 'license', 'label', 'attribution', 'id', 'choice', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time', 'loaded_image', 'detr_preds_count', 'manuscript_count', 'mean_rgb', 'illustration_classifier'],
#     num_rows: 1896
# })

# %% [markdown]
# ## Create DataFrame
#
# We create a DataFrame without the images. This will be used to apply snorkel label functions

# %%
labelled_ds_with_out_image = labelled_ds.remove_columns("loaded_image")

# %%
df = labelled_ds_with_out_image.to_pandas()

# %%
df
# Out:
#                                                   image  \
# 0     https://iiif.archivelab.org/iiif/holylandbible...
# 1     https://iiif.archivelab.org/iiif/ancientgreekf...
# 2     https://iiif.archivelab.org/iiif/saintstheirsy...
# 3     https://iiif.archivelab.org/iiif/orchidaceaeil...
# 4     https://iiif.archivelab.org/iiif/movingpicture...
# ...                                                 ...
# 1891  https://iiif.archivelab.org/iiif/bnf-bpt6k6566...
# 1892  https://iiif.archivelab.org/iiif/atreatiseillu...
# 1893  https://iiif.archivelab.org/iiif/illustrations...
# 1894  https://iiif.archivelab.org/iiif/chaitanyahisc...
# 1895  https://iiif.archivelab.org/iiif/bub_gb_a6QUhG...
#
#                                            manifest_url license label  \
# 0     https://iiif.archivelab.org/iiif/holylandbible...            34
# 1     https://iiif.archivelab.org/iiif/ancientgreekf...           p.
# 2     https://iiif.archivelab.org/iiif/saintstheirsy...            25
# 3     https://iiif.archivelab.org/iiif/orchidaceaeil...           p.
# 4     https://iiif.archivelab.org/iiif/movingpicture...          1339
# ...                                                 ...     ...   ...
# 1891  https://iiif.archivelab.org/iiif/bnf-bpt6k6566...           p.
# 1892  https://iiif.archivelab.org/iiif/atreatiseillu...           p.
# 1893  https://iiif.archivelab.org/iiif/illustrations...            69
# 1894  https://iiif.archivelab.org/iiif/chaitanyahisc...            69
# 1895  https://iiif.archivelab.org/iiif/bub_gb_a6QUhG...           484
#
#                attribution     id           choice  annotator  annotation_id  \
# 0     The Internet Archive  11967  not-illustrated          1           6063
# 1     The Internet Archive  11966      illustrated          1           6062
# 2     The Internet Archive  11965  not-illustrated          1           6061
# 3     The Internet Archive  11964  not-illustrated          1           6060
# 4     The Internet Archive  11963  not-illustrated          1           6059
# ...                    ...    ...              ...        ...            ...
# 1891  The Internet Archive  10007      illustrated          1           4103
# 1892  The Internet Archive  10006      illustrated          1           4102
# 1893  The Internet Archive  10005  not-illustrated          1           4101
# 1894  The Internet Archive  10004  not-illustrated          1           4100
# 1895  The Internet Archive  10003  not-illustrated          1           4099
#
#                            created_at                       updated_at  \
# 0    2022-09-26 09:58:03.514234+00:00 2022-09-26 09:58:03.514258+00:00
# 1    2022-09-26 09:57:59.634415+00:00 2022-09-26 09:57:59.634439+00:00
# 2    2022-09-26 09:57:52.637790+00:00 2022-09-26 09:57:52.637832+00:00
# 3    2022-09-26 09:57:48.066408+00:00 2022-09-26 09:57:48.066436+00:00
# 4    2022-09-26 09:57:43.710760+00:00 2022-09-26 09:57:43.710808+00:00
# ...                               ...                              ...
# 1891 2022-09-15 16:16:51.178485+00:00 2022-09-15 16:16:51.178509+00:00
# 1892 2022-09-15 16:16:49.989463+00:00 2022-09-15 16:16:49.989490+00:00
# 1893 2022-09-15 16:16:48.121866+00:00 2022-09-15 16:16:48.121905+00:00
# 1894 2022-09-15 16:16:47.011223+00:00 2022-09-15 16:16:47.011249+00:00
# 1895 2022-09-15 16:16:45.846795+00:00 2022-09-15 16:16:45.846849+00:00
#
#       lead_time                                   detr_preds_count  \
# 0         3.618                                                 []
# 1         6.742                                                 []
# 2         4.282  [{'box': {'xmax': 2505, 'xmin': 0, 'ymax': 332...
# 3         4.041                                                 []
# 4        19.219  [{'box': {'xmax': 2412, 'xmin': 4, 'ymax': 344...
# ...         ...                                                ...
# 1891      0.946  [{'box': {'xmax': 4241, 'xmin': 29, 'ymax': 53...
# 1892      1.624  [{'box': {'xmax': 784, 'xmin': 485, 'ymax': 97...
# 1893      0.847  [{'box': {'xmax': 3033, 'xmin': 0, 'ymax': 401...
# 1894      0.873  [{'box': {'xmax': 2258, 'xmin': -1, 'ymax': 39...
# 1895      2.533                                                 []
#
#                                        manuscript_count    mean_rgb  \
# 0                                                    []  184.929093
# 1     [{'box': {'xmax': 1372, 'xmin': 282, 'ymax': 2...  223.384461
# 2                                                    []  195.217543
# 3                                                    []  230.156799
# 4                                                    []  198.680118
# ...                                                 ...         ...
# 1891  [{'box': {'xmax': 2845, 'xmin': 462, 'ymax': 4...  201.694078
# 1892                                                 []  161.211220
# 1893                                                 []  217.400830
# 1894                                                 []  172.259406
# 1895                                                 []  239.965382
#
#                                 illustration_classifier
# 0     [{'label': 'not-illustrated', 'score': 0.99810...
# 1     [{'label': 'illustrated', 'score': 0.999426603...
# 2     [{'label': 'not-illustrated', 'score': 0.99941...
# 3     [{'label': 'not-illustrated', 'score': 0.99941...
# 4     [{'label': 'not-illustrated', 'score': 0.99704...
# ...                                                 ...
# 1891  [{'label': 'illustrated', 'score': 0.999818146...
# 1892  [{'label': 'illustrated', 'score': 0.999732792...
# 1893  [{'label': 'not-illustrated', 'score': 0.99934...
# 1894  [{'label': 'not-illustrated', 'score': 0.99901...
# 1895  [{'label': 'not-illustrated', 'score': 0.99926...
#
# [1896 rows x 16 columns]

# %%
df_train, df_valid = train_test_split(df, test_size=0.2)

# %%
ABSTAIN = -1
ILLUSTRATED = 0
NOT_ILLUSTRATED = 1

# %% [markdown]
# ### Creating our Snorkel Labelling functions
#
# These label functions are applied to Snorkel.

# %%
from snorkel.labeling import labeling_function
from snorkel.preprocess import preprocessor

# %%
@labeling_function()
def detr_preds_count_none(x):
    "no objects often means no illustration"
    return NOT_ILLUSTRATED if len(x.detr_preds_count) == 0 else ABSTAIN

# %%
@labeling_function()
def many_detr_objects(x):
    return ILLUSTRATED if len(x.detr_preds_count) >= 2 else ABSTAIN

# %%
@labeling_function()
def manuscript_object(x):
    return ILLUSTRATED if len(x.manuscript_count) >= 2 else ABSTAIN

# %%
@labeling_function()
def manuscript_no_object(x):
    return NOT_ILLUSTRATED if len(x.manuscript_count) == 0 else ABSTAIN

# %%
@labeling_function()
def rgb_above_threshold(x, threshold=250):
    return NOT_ILLUSTRATED if x.mean_rgb >= threshold else ABSTAIN

# %%
@labeling_function()
def rgb_below_threshold(x, threshold=64):
    return NOT_ILLUSTRATED if x.mean_rgb <= threshold else ABSTAIN

# %%
@labeling_function()
def predicted_not_illustrated_high_prob(x):
    return (
        NOT_ILLUSTRATED
        if x.illustration_classifier[0]["label"] == "not-illustrated"
        and x.illustration_classifier[0]["score"] > 0.95
        else ABSTAIN
    )

# %%
@labeling_function()
def predicted_illustrated_high_prob(x):
    return (
        ILLUSTRATED
        if x.illustration_classifier[0]["label"] != "not-illustrated"
        and x.illustration_classifier[0]["score"] > 0.95
        else ABSTAIN
    )

# %% [markdown]
# Combining labelling functions

# %%
lfs = [
    detr_preds_count_none,
    manuscript_no_object,
    many_detr_objects,
    manuscript_object,
    rgb_above_threshold,
    rgb_below_threshold,
    predicted_not_illustrated_high_prob,
    predicted_illustrated_high_prob,
]

# %%
from snorkel.labeling import PandasLFApplier

# %%
applier = PandasLFApplier(lfs=lfs)
L_train = applier.apply(df=df_train)
# Out:
# 100%|██████████| 1516/1516 [00:00<00:00, 12737.05it/s]

# %%
from snorkel.labeling import LFAnalysis

# %%
LFAnalysis(L=L_train, lfs=lfs).lf_summary()
# Out:
#                                      j Polarity  Coverage  Overlaps  Conflicts
# detr_preds_count_none                0      [1]  0.614116  0.613456   0.097625
# manuscript_no_object                 1      [1]  0.725594  0.723615   0.077177
# many_detr_objects                    2      [0]  0.082454  0.082454   0.032322
# manuscript_object                    3      [0]  0.029024  0.029024   0.015172
# rgb_above_threshold                  4      [1]  0.023747  0.023747   0.001319
# rgb_below_threshold                  5      [1]  0.004617  0.004617   0.000000
# predicted_not_illustrated_high_prob  6      [1]  0.746042  0.724934   0.009894
# predicted_illustrated_high_prob      7      [0]  0.246042  0.202507   0.145778

# %%
L_test = applier.apply(df=df_valid)
# Out:
# 100%|██████████| 380/380 [00:00<00:00, 12673.63it/s]

# %%
from snorkel.labeling.model import LabelModel

label_model = LabelModel(cardinality=2, verbose=True)
label_model.fit(L_train=L_train, n_epochs=500, log_freq=100, seed=123)
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 1158.32epoch/s]

# %%
L_test = applier.apply(df=df_valid)
# Out:
# 100%|██████████| 380/380 [00:00<00:00, 11949.76it/s]

# %%
Y_test = df_valid.choice.values

# %%
Y_test = np.array([0 if label == "illustrated" else 1 for label in Y_test])

# %%
label_model_acc = label_model.score(
    L=L_test, Y=Y_test, metrics=["f1", "accuracy"], tie_break_policy="random"
)
label_model_acc
# Out:
# {'f1': 0.9862068965517242, 'accuracy': 0.9789473684210527}

# %%
df
# Out:
#                                                   image  \
# 0     https://iiif.archivelab.org/iiif/holylandbible...
# 1     https://iiif.archivelab.org/iiif/ancientgreekf...
# 2     https://iiif.archivelab.org/iiif/saintstheirsy...
# 3     https://iiif.archivelab.org/iiif/orchidaceaeil...
# 4     https://iiif.archivelab.org/iiif/movingpicture...
# ...                                                 ...
# 1891  https://iiif.archivelab.org/iiif/bnf-bpt6k6566...
# 1892  https://iiif.archivelab.org/iiif/atreatiseillu...
# 1893  https://iiif.archivelab.org/iiif/illustrations...
# 1894  https://iiif.archivelab.org/iiif/chaitanyahisc...
# 1895  https://iiif.archivelab.org/iiif/bub_gb_a6QUhG...
#
#                                            manifest_url license label  \
# 0     https://iiif.archivelab.org/iiif/holylandbible...            34
# 1     https://iiif.archivelab.org/iiif/ancientgreekf...           p.
# 2     https://iiif.archivelab.org/iiif/saintstheirsy...            25
# 3     https://iiif.archivelab.org/iiif/orchidaceaeil...           p.
# 4     https://iiif.archivelab.org/iiif/movingpicture...          1339
# ...                                                 ...     ...   ...
# 1891  https://iiif.archivelab.org/iiif/bnf-bpt6k6566...           p.
# 1892  https://iiif.archivelab.org/iiif/atreatiseillu...           p.
# 1893  https://iiif.archivelab.org/iiif/illustrations...            69
# 1894  https://iiif.archivelab.org/iiif/chaitanyahisc...            69
# 1895  https://iiif.archivelab.org/iiif/bub_gb_a6QUhG...           484
#
#                attribution     id           choice  annotator  annotation_id  \
# 0     The Internet Archive  11967  not-illustrated          1           6063
# 1     The Internet Archive  11966      illustrated          1           6062
# 2     The Internet Archive  11965  not-illustrated          1           6061
# 3     The Internet Archive  11964  not-illustrated          1           6060
# 4     The Internet Archive  11963  not-illustrated          1           6059
# ...                    ...    ...              ...        ...            ...
# 1891  The Internet Archive  10007      illustrated          1           4103
# 1892  The Internet Archive  10006      illustrated          1           4102
# 1893  The Internet Archive  10005  not-illustrated          1           4101
# 1894  The Internet Archive  10004  not-illustrated          1           4100
# 1895  The Internet Archive  10003  not-illustrated          1           4099
#
#                            created_at                       updated_at  \
# 0    2022-09-26 09:58:03.514234+00:00 2022-09-26 09:58:03.514258+00:00
# 1    2022-09-26 09:57:59.634415+00:00 2022-09-26 09:57:59.634439+00:00
# 2    2022-09-26 09:57:52.637790+00:00 2022-09-26 09:57:52.637832+00:00
# 3    2022-09-26 09:57:48.066408+00:00 2022-09-26 09:57:48.066436+00:00
# 4    2022-09-26 09:57:43.710760+00:00 2022-09-26 09:57:43.710808+00:00
# ...                               ...                              ...
# 1891 2022-09-15 16:16:51.178485+00:00 2022-09-15 16:16:51.178509+00:00
# 1892 2022-09-15 16:16:49.989463+00:00 2022-09-15 16:16:49.989490+00:00
# 1893 2022-09-15 16:16:48.121866+00:00 2022-09-15 16:16:48.121905+00:00
# 1894 2022-09-15 16:16:47.011223+00:00 2022-09-15 16:16:47.011249+00:00
# 1895 2022-09-15 16:16:45.846795+00:00 2022-09-15 16:16:45.846849+00:00
#
#       lead_time                                   detr_preds_count  \
# 0         3.618                                                 []
# 1         6.742                                                 []
# 2         4.282  [{'box': {'xmax': 2505, 'xmin': 0, 'ymax': 332...
# 3         4.041                                                 []
# 4        19.219  [{'box': {'xmax': 2412, 'xmin': 4, 'ymax': 344...
# ...         ...                                                ...
# 1891      0.946  [{'box': {'xmax': 4241, 'xmin': 29, 'ymax': 53...
# 1892      1.624  [{'box': {'xmax': 784, 'xmin': 485, 'ymax': 97...
# 1893      0.847  [{'box': {'xmax': 3033, 'xmin': 0, 'ymax': 401...
# 1894      0.873  [{'box': {'xmax': 2258, 'xmin': -1, 'ymax': 39...
# 1895      2.533                                                 []
#
#                                        manuscript_count    mean_rgb  \
# 0                                                    []  184.929093
# 1     [{'box': {'xmax': 1372, 'xmin': 282, 'ymax': 2...  223.384461
# 2                                                    []  195.217543
# 3                                                    []  230.156799
# 4                                                    []  198.680118
# ...                                                 ...         ...
# 1891  [{'box': {'xmax': 2845, 'xmin': 462, 'ymax': 4...  201.694078
# 1892                                                 []  161.211220
# 1893                                                 []  217.400830
# 1894                                                 []  172.259406
# 1895                                                 []  239.965382
#
#                                 illustration_classifier
# 0     [{'label': 'not-illustrated', 'score': 0.99810...
# 1     [{'label': 'illustrated', 'score': 0.999426603...
# 2     [{'label': 'not-illustrated', 'score': 0.99941...
# 3     [{'label': 'not-illustrated', 'score': 0.99941...
# 4     [{'label': 'not-illustrated', 'score': 0.99704...
# ...                                                 ...
# 1891  [{'label': 'illustrated', 'score': 0.999818146...
# 1892  [{'label': 'illustrated', 'score': 0.999732792...
# 1893  [{'label': 'not-illustrated', 'score': 0.99934...
# 1894  [{'label': 'not-illustrated', 'score': 0.99901...
# 1895  [{'label': 'not-illustrated', 'score': 0.99926...
#
# [1896 rows x 16 columns]

# %%
labelled_ds
# Out:
# Dataset({
#     features: ['image', 'manifest_url', 'license', 'label', 'attribution', 'id', 'choice', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time', 'loaded_image', 'detr_preds_count', 'manuscript_count', 'mean_rgb', 'illustration_classifier'],
#     num_rows: 1896
# })

# %%
L_train = applier.apply(df=df)
# Out:
# 100%|██████████| 1896/1896 [00:00<00:00, 12928.69it/s]

# %%
probs_train = label_model.predict_proba(L_train)

# %%
len(probs_train)
# Out:
# 1896

# %%
probs_train.max(axis=1)
# Out:
# array([0.90770403, 0.99976089, 0.85902286, ..., 0.85902286, 0.85902286,
#        0.90770403])

# %%
from snorkel.utils import probs_to_preds

# %%
probs_to_preds(probs_train)
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
mask = (L_train != -1).any(axis=1)
mask
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
len(probs_train[mask])
# Out:
# 1894

# %%
df_train_filtered.iloc[0][0]
# Out:
# 'https://iiif.archivelab.org/iiif/holylandbiblebok0000cunn$49/full/full/0/default.jpg'

# %%
labelled_ds.select(mask)
# Out:
# Dataset({
#     features: ['image', 'manifest_url', 'license', 'label', 'attribution', 'id', 'choice', 'annotator', 'annotation_id', 'created_at', 'updated_at', 'lead_time', 'loaded_image', 'detr_preds_count', 'manuscript_count', 'mean_rgb', 'illustration_classifier'],
#     num_rows: 1896
# })

# %%
(probs_train != -1).any(axis=1)
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
unlabelled_ds = unlabelled_ds.map(
    pre_process, batched=True, batch_size=512, writer_batch_size=1024
)
# Out:
#   0%|          | 0/131 [00:00<?, ?ba/s]
# /usr/local/lib/python3.7/dist-packages/transformers/pipelines/base.py:1046: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   UserWarning,

# %%
unlabelled_ds_without_image = unlabelled_ds.remove_columns("loaded_image")

# %%
df_full = unlabelled_ds_without_image.to_pandas()

# %%
df_full
# Out:
#                                                    image  \
# 0      https://iiif.archivelab.org/iiif/historicalcol...
# 1      https://iiif.archivelab.org/iiif/notesonscienc...
# 2      https://iiif.archivelab.org/iiif/scandinavianf...
# 3      https://iiif.archivelab.org/iiif/cataloguepict...
# 4      https://iiif.archivelab.org/iiif/illustratedit...
# ...                                                  ...
# 66831  https://iiif.archivelab.org/iiif/narrativedisc...
# 66832  https://iiif.archivelab.org/iiif/landscapeillu...
# 66833  https://iiif.archivelab.org/iiif/rice-lewis-il...
# 66834  https://iiif.archivelab.org/iiif/villageworkin...
# 66835  https://iiif.archivelab.org/iiif/cu31924032188...
#
#                                             manifest_url  license label  \
# 0      https://iiif.archivelab.org/iiif/historicalcol...      NaN   263
# 1      https://iiif.archivelab.org/iiif/notesonscienc...      NaN   p.
# 2      https://iiif.archivelab.org/iiif/scandinavianf...      NaN   334
# 3      https://iiif.archivelab.org/iiif/cataloguepict...      NaN   336
# 4      https://iiif.archivelab.org/iiif/illustratedit...      NaN   107
# ...                                                  ...      ...   ...
# 66831  https://iiif.archivelab.org/iiif/narrativedisc...      NaN   p.
# 66832  https://iiif.archivelab.org/iiif/landscapeillu...      NaN   p.
# 66833  https://iiif.archivelab.org/iiif/rice-lewis-il...      NaN   734
# 66834  https://iiif.archivelab.org/iiif/villageworkin...      NaN    41
# 66835  https://iiif.archivelab.org/iiif/cu31924032188...      NaN   147
#
#                 attribution  \
# 0      The Internet Archive
# 1      The Internet Archive
# 2      The Internet Archive
# 3      The Internet Archive
# 4      The Internet Archive
# ...                     ...
# 66831  The Internet Archive
# 66832  The Internet Archive
# 66833  The Internet Archive
# 66834  The Internet Archive
# 66835  The Internet Archive
#
#                                         detr_preds_count  \
# 0      [{'box': {'xmax': 249, 'xmin': 0, 'ymax': 250,...
# 1      [{'box': {'xmax': 249, 'xmin': 0, 'ymax': 250,...
# 2      [{'box': {'xmax': 249, 'xmin': 0, 'ymax': 250,...
# 3                                                     []
# 4      [{'box': {'xmax': 249, 'xmin': 0, 'ymax': 250,...
# ...                                                  ...
# 66831                                                 []
# 66832                                                 []
# 66833  [{'box': {'xmax': 229, 'xmin': 150, 'ymax': 19...
# 66834                                                 []
# 66835                                                 []
#
#                                         manuscript_count    mean_rgb  \
# 0      [{'box': {'xmax': 96, 'xmin': 45, 'ymax': 174,...  179.541067
# 1                                                     []  205.527088
# 2                                                     []  195.941051
# 3                                                     []  222.432368
# 4                                                     []  197.561888
# ...                                                  ...         ...
# 66831                                                 []  203.316592
# 66832  [{'box': {'xmax': 205, 'xmin': 35, 'ymax': 71,...  245.947008
# 66833                                                 []  173.834384
# 66834                                                 []  185.071595
# 66835                                                 []  231.910064
#
#                                  illustration_classifier
# 0      [{'label': 'illustrated', 'score': 0.999695539...
# 1      [{'label': 'not-illustrated', 'score': 0.99895...
# 2      [{'label': 'not-illustrated', 'score': 0.99932...
# 3      [{'label': 'not-illustrated', 'score': 0.99954...
# 4      [{'label': 'not-illustrated', 'score': 0.99909...
# ...                                                  ...
# 66831  [{'label': 'not-illustrated', 'score': 0.99955...
# 66832  [{'label': 'not-illustrated', 'score': 0.99859...
# 66833  [{'label': 'illustrated', 'score': 0.999768555...
# 66834  [{'label': 'not-illustrated', 'score': 0.99904...
# 66835  [{'label': 'not-illustrated', 'score': 0.99874...
#
# [66836 rows x 9 columns]

# %%
L_train = applier.apply(df=df_full)
# Out:
# 100%|██████████| 66836/66836 [00:05<00:00, 12935.20it/s]

# %%
LFAnalysis(L=L_train, lfs=lfs).lf_summary()
# Out:
#                                      j Polarity  Coverage  Overlaps  Conflicts
# detr_preds_count_none                0      [1]  0.590999  0.589278   0.089084
# manuscript_no_object                 1      [1]  0.809923  0.805240   0.092944
# many_detr_objects                    2      [0]  0.070217  0.070142   0.024478
# manuscript_object                    3      [0]  0.016698  0.016698   0.006793
# rgb_above_threshold                  4      [1]  0.026213  0.026198   0.000584
# rgb_below_threshold                  5      [1]  0.004638  0.004623   0.000658
# predicted_not_illustrated_high_prob  6      [1]  0.745796  0.742190   0.003441
# predicted_illustrated_high_prob      7      [0]  0.237387  0.190736   0.140568

# %%
label_model = LabelModel(cardinality=2, verbose=True)
label_model.fit(L_train=L_train, n_epochs=500, log_freq=100, seed=123)
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 1254.01epoch/s]

# %%
probs_train = label_model.predict_proba(L_train)

# %%
len(probs_train) == len(unlabelled_ds)
# Out:
# True

# %%
unlabelled_ds_with_probs = unlabelled_ds.add_column(
    "snorkel_label_model_probs", probs_train.tolist()
)

# %%
unlabelled_ds_with_probs[0]
# Out:
# {'image': 'https://iiif.archivelab.org/iiif/historicalcollec01howe_1$258/full/full/0/default.jpg',
#  'manifest_url': 'https://iiif.archivelab.org/iiif/historicalcollec01howe_1/manifest.json',
#  'license': None,
#  'label': '263',
#  'attribution': 'The Internet Archive',
#  'loaded_image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x7F230BDCBF10>,
#  'detr_preds_count': [{'box': {'xmax': 249, 'xmin': 0, 'ymax': 250, 'ymin': 0},
#    'label': 'laptop',
#    'score': 0.9441924691200256}],
#  'manuscript_count': [{'box': {'xmax': 96,
#     'xmin': 45,
#     'ymax': 174,
#     'ymin': 113},
#    'label': 'early_printed_illustration',
#    'score': 0.9674574732780457}],
#  'mean_rgb': 179.54106666666667,
#  'illustration_classifier': [{'label': 'illustrated',
#    'score': 0.9996955394744873},
#   {'label': 'not-illustrated', 'score': 0.0003044367767870426}],
#  'snorkel_label_model_probs': [0.9999849810676339, 1.5018932366001192e-05]}

# %%
from snorkel.utils import probs_to_preds

arg_max_preds = probs_to_preds(probs_train)

# %%
unlabelled_ds_with_snorkel_labels = unlabelled_ds_with_probs.add_column(
    "snorkel_label", arg_max_preds
)

# %%
unlabelled_ds_with_snorkel_labels[0]
# Out:
# {'image': 'https://iiif.archivelab.org/iiif/historicalcollec01howe_1$258/full/full/0/default.jpg',
#  'manifest_url': 'https://iiif.archivelab.org/iiif/historicalcollec01howe_1/manifest.json',
#  'license': None,
#  'label': '263',
#  'attribution': 'The Internet Archive',
#  'loaded_image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x7F22C79D5DD0>,
#  'detr_preds_count': [{'box': {'xmax': 249, 'xmin': 0, 'ymax': 250, 'ymin': 0},
#    'label': 'laptop',
#    'score': 0.9441924691200256}],
#  'manuscript_count': [{'box': {'xmax': 96,
#     'xmin': 45,
#     'ymax': 174,
#     'ymin': 113},
#    'label': 'early_printed_illustration',
#    'score': 0.9674574732780457}],
#  'mean_rgb': 179.54106666666667,
#  'illustration_classifier': [{'label': 'illustrated',
#    'score': 0.9996955394744873},
#   {'label': 'not-illustrated', 'score': 0.0003044367767870426}],
#  'snorkel_label_model_probs': [0.9999849810676339, 1.5018932366001192e-05],
#  'snorkel_label': 0}

# %%
import datasets

# %%
unlabelled_ds_with_snorkel_labels = unlabelled_ds_with_snorkel_labels.cast_column(
    "snorkel_label", datasets.ClassLabel(names=["illustrated", "not-illustrated"])
)
# Out:
# Casting the dataset:   0%|          | 0/7 [00:00<?, ?ba/s]

# %%
unlabelled_ds_with_snorkel_labels.push_to_hub(
    "ImageIN/unlabelled_IA_with_snorkel_labels", private=True
)
# Out:
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_deprecation.py:97: FutureWarning: Deprecated argument(s) used in 'dataset_info': token. Will not be supported from version '0.12'.
#   warnings.warn(message, FutureWarning)
#   0%|          | 0/23 [00:00<?, ?ba/s]
# Pushing dataset shards to the dataset hub:   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/23 [00:00<?, ?ba/s]
#   0%|          | 0/23 [00:00<?, ?ba/s]
# Deleting unused files from dataset repository:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading metadata:   0%|          | 0.00/4.52k [00:00<?, ?B/s]
# WARNING:datasets.arrow_dataset:Updating downloaded metadata with the new split.
