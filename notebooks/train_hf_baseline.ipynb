# %%
# !sudo apt install git-lfs --upgrade
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git-lfs is already the newest version (2.3.4-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.

# %%
# !git init .
# !git lfs install
# Out:
# Initialized empty Git repository in /content/.git/
# Updated git hooks.
# Git LFS initialized.

# %%
# %%capture
# !pip install datasets transformers wandb

# %%
import wandb
from datasets import load_dataset
from transformers import (
    AutoFeatureExtractor,
    AutoModelForImageClassification,
    Trainer,
    TrainingArguments,
)
from sklearn.model_selection import StratifiedShuffleSplit
from torchvision.transforms import (
    CenterCrop,
    RandomErasing,
    RandomAutocontrast,
    Compose,
    Normalize,
    RandomHorizontalFlip,
    RandomResizedCrop,
    Resize,
    RandomAdjustSharpness,
    ToTensor,
)
import torch
import datasets
import numpy as np
from datasets import load_metric
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]

# %%
# %env WANDB_PROJECT=imagein
# %env WANDB_ENTITY=davanstrien
# Out:
# env: WANDB_PROJECT=imagein
# env: WANDB_ENTITY=davanstrien

# %%
wandb.login()
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
MODEL_CHECKPOINT = "facebook/convnext-base-224"
DATASET_CHECKPOINT = "ImageIN/ImageIn_annotations"

# %%
FP_16 = torch.cuda.is_available()

# %%
dataset = load_dataset(DATASET_CHECKPOINT, split="train")
# Out:
# WARNING:datasets.builder:Using custom data configuration ImageIN--ImageIn_annotations-3c053cc2ce1c24bf
# WARNING:datasets.builder:Found cached dataset parquet (/root/.cache/huggingface/datasets/ImageIN___parquet/ImageIN--ImageIn_annotations-3c053cc2ce1c24bf/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)

# %%
dataset.column_names
# Out:
# ['image',
#  'manifest_url',
#  'license',
#  'label',
#  'attribution',
#  'id',
#  'choice',
#  'annotator',
#  'annotation_id',
#  'created_at',
#  'updated_at',
#  'lead_time',
#  'loaded_image']

# %%
dataset = dataset.remove_columns(
    [name for name in dataset.column_names if name not in {"loaded_image", "choice"}]
)

# %%
dataset = dataset.rename_column("choice", "labels")

# %%
labels = dataset.unique("labels")

# %%
dataset = dataset.cast_column("labels", datasets.ClassLabel(names=labels))
# Out:
# Casting the dataset:   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
dataset = dataset.train_test_split(0.3, stratify_by_column="labels", seed=42)

# %%
train_ds, valid_ds = dataset["train"], dataset["test"]

# %%
def prepare_transforms(model_checkpoint, train_ds, valid_ds, test_ds=None):
    feature_extractor = AutoFeatureExtractor.from_pretrained(model_checkpoint)
    normalize = Normalize(
        mean=feature_extractor.image_mean, std=feature_extractor.image_std
    )
    _train_transforms = Compose(
        [
            Resize((feature_extractor.size, feature_extractor.size)),
            RandomAdjustSharpness(0.1),
            RandomAutocontrast(),
            ToTensor(),
            normalize,
            RandomErasing(),
        ]
    )

    _val_transforms = Compose(
        [
            Resize((feature_extractor.size, feature_extractor.size)),
            ToTensor(),
            normalize,
        ]
    )

    def train_transforms(examples):
        examples["pixel_values"] = [
            _train_transforms(image.convert("RGB"))
            for image in examples["loaded_image"]
        ]
        return examples

    def val_transforms(examples):
        examples["pixel_values"] = [
            _val_transforms(image.convert("RGB")) for image in examples["loaded_image"]
        ]
        return examples

    train_ds.set_transform(train_transforms)
    valid_ds.set_transform(val_transforms)

    return train_ds, valid_ds

# %%
train_ds, valid_ds = prepare_transforms(MODEL_CHECKPOINT, train_ds, valid_ds)
# Out:
# loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--facebook--convnext-base-224/snapshots/eda2970bc74154a2af92300316deecd49f72bea8/preprocessor_config.json
# Feature extractor ConvNextFeatureExtractor {
#   "crop_pct": 0.875,
#   "do_normalize": true,
#   "do_resize": true,
#   "feature_extractor_type": "ConvNextFeatureExtractor",
#   "image_mean": [
#     0.485,
#     0.456,
#     0.406
#   ],
#   "image_std": [
#     0.229,
#     0.224,
#     0.225
#   ],
#   "resample": 3,
#   "size": 224
# }

# %%
train_ds
# Out:
# Dataset({
#     features: ['labels', 'loaded_image'],
#     num_rows: 1327
# })

# %%
def collate_fn(examples):
    pixel_values = torch.stack([example["pixel_values"] for example in examples])
    labels = torch.tensor([example["labels"] for example in examples])
    return {"pixel_values": pixel_values, "labels": labels}

# %%
id2label = dict(enumerate(train_ds.features["labels"].names))
label2id = {v: k for k, v in id2label.items()}

# %%
model = AutoModelForImageClassification.from_pretrained(
    MODEL_CHECKPOINT,
    num_labels=len(id2label),
    id2label=id2label,
    label2id=label2id,
    ignore_mismatched_sizes=True,
)
# Out:
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--facebook--convnext-base-224/snapshots/eda2970bc74154a2af92300316deecd49f72bea8/config.json
# Model config ConvNextConfig {
#   "_name_or_path": "facebook/convnext-base-224",
#   "architectures": [
#     "ConvNextForImageClassification"
#   ],
#   "depths": [
#     3,
#     3,
#     27,
#     3
#   ],
#   "drop_path_rate": 0.0,
#   "hidden_act": "gelu",
#   "hidden_sizes": [
#     128,
#     256,
#     512,
#     1024
#   ],
#   "id2label": {
#     "0": "not-illustrated",
#     "1": "illustrated"
#   },
#   "image_size": 224,
#   "initializer_range": 0.02,
#   "label2id": {
#     "illustrated": 1,
#     "not-illustrated": 0
#   },
#   "layer_norm_eps": 1e-12,
#   "layer_scale_init_value": 1e-06,
#   "model_type": "convnext",
#   "num_channels": 3,
#   "num_stages": 4,
#   "patch_size": 4,
#   "torch_dtype": "float32",
#   "transformers_version": "4.22.1"
# }
#
# loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--facebook--convnext-base-224/snapshots/eda2970bc74154a2af92300316deecd49f72bea8/pytorch_model.bin
# All model checkpoint weights were used when initializing ConvNextForImageClassification.
#
# Some weights of ConvNextForImageClassification were not initialized from the model checkpoint at facebook/convnext-base-224 and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([1000, 1024]) in the checkpoint and torch.Size([2, 1024]) in the model instantiated
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([2]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model_name = MODEL_CHECKPOINT.split("/")[1]
dataset_name = DATASET_CHECKPOINT.split("/")[1]

# %%
args = TrainingArguments(
    "imagein",
    save_strategy="epoch",
    evaluation_strategy="epoch",
    hub_model_id=f"ImageIN/{model_name}_finetuned_on_{dataset_name}",
    overwrite_output_dir=True,
    push_to_hub=True,
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=50,
    weight_decay=0.1,
    disable_tqdm=False,
    fp16=FP_16,
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    logging_dir="logs",
    remove_unused_columns=False,
    save_total_limit=1,
    seed=42,
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
feature_extractor = AutoFeatureExtractor.from_pretrained(MODEL_CHECKPOINT)
# Out:
# loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--facebook--convnext-base-224/snapshots/eda2970bc74154a2af92300316deecd49f72bea8/preprocessor_config.json
# Feature extractor ConvNextFeatureExtractor {
#   "crop_pct": 0.875,
#   "do_normalize": true,
#   "do_resize": true,
#   "feature_extractor_type": "ConvNextFeatureExtractor",
#   "image_mean": [
#     0.485,
#     0.456,
#     0.406
#   ],
#   "image_std": [
#     0.229,
#     0.224,
#     0.225
#   ],
#   "resample": 3,
#   "size": 224
# }

# %%
def compute_metrics(eval_pred):
    precision_metric = load_metric("precision")
    recall_metric = load_metric("recall")
    f1_metric = load_metric("f1")
    accuracy_metric = load_metric("accuracy")

    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    precision = precision_metric.compute(
        predictions=predictions, references=labels, average="macro"
    )["precision"]
    recall = recall_metric.compute(
        predictions=predictions, references=labels, average="macro"
    )["recall"]
    f1 = f1_metric.compute(predictions=predictions, references=labels, average="macro")[
        "f1"
    ]
    accuracy = accuracy_metric.compute(predictions=predictions, references=labels)[
        "accuracy"
    ]
    return {"precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy}

# %%
from huggingface_hub import notebook_login

# %%
notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %%
# !git config --global credential.helper store

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=train_ds,
    eval_dataset=valid_ds,
    data_collator=collate_fn,
    compute_metrics=compute_metrics,
    tokenizer=feature_extractor,
)
# Out:
# /content/imagein is already a clone of https://huggingface.co/ImageIN/convnext-base-224_finetuned_on_ImageIn_annotations. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:/content/imagein is already a clone of https://huggingface.co/ImageIN/convnext-base-224_finetuned_on_ImageIn_annotations. Make sure you pull the latest changes with `repo.git_pull()`.
# Using cuda_amp half precision backend

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 1327
#   Num Epochs = 50
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 4150
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
#     <div>
#
#       <progress value='250' max='4150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 250/4150 12:58 < 3:24:03, 0.32 it/s, Epoch 3/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.136823</td>
#       <td>0.974817</td>
#       <td>0.963195</td>
#       <td>0.968832</td>
#       <td>0.977153</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.073367</td>
#       <td>0.975038</td>
#       <td>0.972744</td>
#       <td>0.973884</td>
#       <td>0.980668</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='20' max='36' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/36 00:37 < 00:31, 0.50 it/s]
#     </div>
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
# Downloading builder script:   0%|          | 0.00/2.58k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.52k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/1.65k [00:00<?, ?B/s]
# Saving model checkpoint to imagein/checkpoint-83
# Configuration saved in imagein/checkpoint-83/config.json
# Model weights saved in imagein/checkpoint-83/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-83/preprocessor_config.json
# Feature extractor saved in imagein/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-166
# Configuration saved in imagein/checkpoint-166/config.json
# Model weights saved in imagein/checkpoint-166/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint
pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-581/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-498] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-664
# Configuration saved in imagein/checkpoint-664/config.json
# Model weights saved in imagein/checkpoint-664/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-664/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-747
# Configuration saved in imagein/checkpoint-747/config.json
# Model weights saved in imagein/checkpoint-747/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-747/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-581] due to args.save_total_limit
# Deleting older checkpoint [imagein/checkpoint-664] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-830
# Configuration saved in imagein/checkpoint-830/config.json
# Model weights saved in imagein/checkpoint-830/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-830/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-913
# Configuration saved in imagein/checkpoint-913/config.json
# Model weights saved in imagein/checkpoint-913/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-913/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-830] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-996
# Configuration saved in imagein/checkpoint-996/config.json
# Model weights saved in imagein/checkpoint-996/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-996/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-913] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-1079
# Configuration saved in imagein/checkpoint-1079/config.json
# Model weights saved in imagein/checkpoint-1079/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-1079/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-996] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-1162
# Configuration saved in imagein/checkpoint-1162/config.json
# Model weights saved in imagein/checkpoint-1162/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-1162/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-747] due to args.save_total_limit
# Deleting older checkpoint [imagein/checkpoint-1079] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-1245
# Configuration saved in imagein/checkpoint-1245/config.json
# Model weights saved in imagein/checkpoint-1245/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-1245/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-1162] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-1328
# Configuration saved in imagein/checkpoint-1328/config.json
# Model weights saved in imagein/checkpoint-1328/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-1328/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-1411
# Configuration saved in imagein/checkpoint-1411/config.json
# Model weights saved in imagein/checkpoint-1411/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-1411/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-1328] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-1494
# Configuration saved in imagein/checkpoint-1494/config.json
# Model weights saved in imagein/checkpoint-1494/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-1494/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-1245] due to args.save_total_limit
# Deleting older checkpoint [imagein/checkpoint-1411] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-1577
# Configuration saved in imagein/checkpoint-1577/config.json
# Model weights saved in imagein/checkpoint-1577/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-1577/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-1660
# Configuration saved in imagein/checkpoint-1660/config.json
# Model weights saved in imagein/checkpoint-1660/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-1660/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-1577] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-1743
# Configuration saved in imagein/checkpoint-1743/config.json
# Model weights saved in imagein/checkpoint-1743/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-1743/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-1660] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-1826
# Configuration saved in imagein/checkpoint-1826/config.json
# Model weights saved in imagein/checkpoint-1826/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-1826/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-1743] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-1909
# Configuration saved in imagein/checkpoint-1909/config.json
# Model weights saved in imagein/checkpoint-1909/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-1909/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-1826] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-1992
# Configuration saved in imagein/checkpoint-1992/config.json
# Model weights saved in imagein/checkpoint-1992/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-1992/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-1909] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-2075
# Configuration saved in imagein/checkpoint-2075/config.json
# Model weights saved in imagein/checkpoint-2075/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-2075/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-1992] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-2158
# Configuration saved in imagein/checkpoint-2158/config.json
# Model weights saved in imagein/checkpoint-2158/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-2158/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-2075] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-2241
# Configuration saved in imagein/checkpoint-2241/config.json
# Model weights saved in imagein/checkpoint-2241/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-2241/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-2158] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-2324
# Configuration saved in imagein/checkpoint-2324/config.json
# Model weights saved in imagein/checkpoint-2324/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-2324/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-2241] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-2407
# Configuration saved in imagein/checkpoint-2407/config.json
# Model weights saved in imagein/checkpoint-2407/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-2407/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-2324] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-2490
# Configuration saved in imagein/checkpoint-2490/config.json
# Model weights saved in imagein/checkpoint-2490/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-2490/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-1494] due to args.save_total_limit
# Deleting older checkpoint [imagein/checkpoint-2407] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-2573
# Configuration saved in imagein/checkpoint-2573/config.json
# Model weights saved in imagein/checkpoint-2573/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-2573/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-2656
# Configuration saved in imagein/checkpoint-2656/config.json
# Model weights saved in imagein/checkpoint-2656/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-2656/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-2573] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-2739
# Configuration saved in imagein/checkpoint-2739/config.json
# Model weights saved in imagein/checkpoint-2739/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-2739/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-2656] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-2822
# Configuration saved in imagein/checkpoint-2822/config.json
# Model weights saved in imagein/checkpoint-2822/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-2822/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-2490] due to args.save_total_limit
# Deleting older checkpoint [imagein/checkpoint-2739] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-2905
# Configuration saved in imagein/checkpoint-2905/config.json
# Model weights saved in imagein/checkpoint-2905/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-2905/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-2988
# Configuration saved in imagein/checkpoint-2988/config.json
# Model weights saved in imagein/checkpoint-2988/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-2988/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-2905] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-3071
# Configuration saved in imagein/checkpoint-3071/config.json
# Model weights saved in imagein/checkpoint-3071/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-3071/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-2822] due to args.save_total_limit
# Deleting older checkpoint [imagein/checkpoint-2988] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-3154
# Configuration saved in imagein/checkpoint-3154/config.json
# Model weights saved in imagein/checkpoint-3154/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-3154/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-3237
# Configuration saved in imagein/checkpoint-3237/config.json
# Model weights saved in imagein/checkpoint-3237/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-3237/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-3154] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-3320
# Configuration saved in imagein/checkpoint-3320/config.json
# Model weights saved in imagein/checkpoint-3320/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-3320/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-3237] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-3403
# Configuration saved in imagein/checkpoint-3403/config.json
# Model weights saved in imagein/checkpoint-3403/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-3403/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-3320] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-3486
# Configuration saved in imagein/checkpoint-3486/config.json
# Model weights saved in imagein/checkpoint-3486/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-3486/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-3403] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-3569
# Configuration saved in imagein/checkpoint-3569/config.json
# Model weights saved in imagein/checkpoint-3569/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-3569/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-3486] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-3652
# Configuration saved in imagein/checkpoint-3652/config.json
# Model weights saved in imagein/checkpoint-3652/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-3652/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-3569] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-3735
# Configuration saved in imagein/checkpoint-3735/config.json
# Model weights saved in imagein/checkpoint-3735/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-3735/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-3652] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-3818
# Configuration saved in imagein/checkpoint-3818/config.json
# Model weights saved in imagein/checkpoint-3818/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-3818/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-3735] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-3901
# Configuration saved in imagein/checkpoint-3901/config.json
# Model weights saved in imagein/checkpoint-3901/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-3901/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-3818] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-3984
# Configuration saved in imagein/checkpoint-3984/config.json
# Model weights saved in imagein/checkpoint-3984/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-3984/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-3901] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-4067
# Configuration saved in imagein/checkpoint-4067/config.json
# Model weights saved in imagein/checkpoint-4067/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-4067/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-3984] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 569
#   Batch size = 16
# Saving model checkpoint to imagein/checkpoint-4150
# Configuration saved in imagein/checkpoint-4150/config.json
# Model weights saved in imagein/checkpoint-4150/pytorch_model.bin
# Feature extractor saved in imagein/checkpoint-4150/preprocessor_config.json
# Deleting older checkpoint [imagein/checkpoint-4067] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from imagein/checkpoint-3071 (score: 0.9836161329466693).
# TrainOutput(global_step=4150, training_loss=0.02293248847306493, metrics={'train_runtime': 13997.5317, 'train_samples_per_second': 4.74, 'train_steps_per_second': 0.296, 'total_flos': 5.247560434933555e+18, 'train_loss': 0.02293248847306493, 'epoch': 50.0})

# %%
trainer.push_to_hub("training finished")
# Out:
# Saving model checkpoint to imagein
# Configuration saved in imagein/config.json
# Model weights saved in imagein/pytorch_model.bin
# Feature extractor saved in imagein/preprocessor_config.json
# Several commits (2) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# WARNING:huggingface_hub.repository:The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          | 3.34k/334M [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/ImageIN/convnext-base-224_finetuned_on_ImageIn_annotations
#    0ad80c6..806682f  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/ImageIN/convnext-base-224_finetuned_on_ImageIn_annotations
#    0ad80c6..806682f  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Image Classification', 'type': 'image-classification'}, 'metrics': [{'name': 'Precision', 'type': 'precision', 'value': 0.9721650326797385}, {'name': 'Recall', 'type': 'recall', 'value': 0.981127206127206}, {'name': 'F1', 'type': 'f1', 'value': 0.976539565260415}, {'name': 'Accuracy', 'type': 'accuracy', 'value': 0.9824253075571178}]}
# To https://huggingface.co/ImageIN/convnext-base-224_finetuned_on_ImageIn_annotations
#    806682f..465db3b  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/ImageIN/convnext-base-224_finetuned_on_ImageIn_annotations
#    806682f..465db3b  main -> main
# 'https://huggingface.co/ImageIN/convnext-base-224_finetuned_on_ImageIn_annotations/commit/806682f1c4021bf3bf36f4a6c4087c6966d62cb0'

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▃▃▃▃▃▃▅▃▅▃▅▂▆▇▅▆▆▃▇▅▆▅▁▆▇▇█▇█▇▇▇▆▇▇▇▇▆▅</td></tr><tr><td>eval/f1</td><td>▁▃▃▃▃▄▄▅▃▅▃▅▂▆▇▅▆▆▃▇▅▆▅▂▆▇▇█▇█▇▇▇▆▇▇▇▇▆▅</td></tr><tr><td>eval/loss</td><td>█▂▂▂▂▁▁▂▃▂▃▂▄▂▂▂▃▃▃▂▃▃▂▆▂▂▃▁▂▁▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>eval/precision</td><td>▆▆▆▆▆▄▄▇▆▇▆▅▆▇▇▅▇▇▆█▇▇▄▁▅▆▆█▆▇██▆▅▆▆██▆▅</td></tr><tr><td>eval/recall</td><td>▁▄▄▄▄▅▅▅▄▅▄▆▃▅▇▆▅▅▄▆▅▅▇▆▇██▇██▆▆█▇██▆▆▇▆</td></tr><tr><td>eval/runtime</td><td>▃█▁▂▂▁▂▂▁▃▁▃▄▂▂▂▂▃▃▂▂▄▃▃▃▃▂▃▃▃▄▂▂▃▃▃▃▂▃▂</td></tr><tr><td>eval/samples_per_second</td><td>▆▁█▇▇█▇▇█▆█▆▅▇▇▇▆▅▆▇▇▅▆▆▆▆▆▆▆▆▅▇▇▆▆▆▆▇▆▇</td></tr><tr><td>eval/steps_per_second</td><td>▆▁█▇▇█▇▇█▆█▆▅▇▇▇▆▅▆▇▇▅▆▆▆▆▇▆▆▆▅▇▇▆▆▆▆▇▆▇</td></tr><tr><td>train/epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>train/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>train/learning_rate</td><td>█▇▆▅▄▃▂▁</td></tr><tr><td>train/loss</td><td>█▂▂▁▁▂▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.98243</td></tr><tr><td>eval/f1</td><td>0.97654</td></tr><tr><td>eval/loss</td><td>0.07492</td></tr><tr><td>eval/precision</td><td>0.97217</td></tr><tr><td>eval/recall</td><td>0.98113</td></tr><tr><td>eval/runtime</td><td>77.1187</td></tr><tr><td>eval/samples_per_second</td><td>7.378</td></tr><tr><td>eval/steps_per_second</td><td>0.467</td></tr><tr><td>train/epoch</td><td>50.0</td></tr><tr><td>train/global_step</td><td>4150</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.0082</td></tr><tr><td>train/total_flos</td><td>5.247560434933555e+18</td></tr><tr><td>train/train_loss</td><td>0.02293</td></tr><tr><td>train/train_runtime</td><td>13997.5317</td></tr><tr><td>train/train_samples_per_second</td><td>4.74</td></tr><tr><td>train/train_steps_per_second</td><td>0.296</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">imagein</strong>: <a href="https://wandb.ai/davanstrien/imagein/runs/2gpqh7d3" target="_blank">https://wandb.ai/davanstrien/imagein/runs/2gpqh7d3</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220926_122944-2gpqh7d3/logs</code>
